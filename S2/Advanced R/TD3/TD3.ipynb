# %%
library(tidyverse)
# Out:
# Warning message:
# "package 'tidyverse' was built under R version 3.6.2"-- Attaching packages --------------------------------------- tidyverse 1.3.0 --
# v ggplot2 3.2.1     v purrr   0.3.3
# v tibble  2.1.3     v dplyr   0.8.3
# v tidyr   1.0.0     v stringr 1.4.0
# v readr   1.3.1     v forcats 0.4.0
# Warning message:
# "package 'tidyr' was built under R version 3.6.2"Warning message:
# "package 'dplyr' was built under R version 3.6.2"-- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter()  masks stats::filter()
# x purrr::flatten() masks jsonlite::flatten()
# x dplyr::lag()     masks stats::lag()

# %% [markdown]
# On se trouve au point de coordonnées (48.1179151,-1.7028661). Créer une table avec le nom des troisstations les plus proches classées par ordre de distance et le nombre d’emplacements libres dans cesstations

# %%
etat <- read_csv("../DATA/etat-des-stations-le-velo-star-en-temps-reel.csv")
topo <- read_csv("../DATA/topologie-des-stations-le-velo-star.csv")
# Out:
# Parsed with column specification:
# cols(
#   id = col_double(),
#   nom = col_character(),
#   latitude = col_double(),
#   longitude = col_double(),
#   etat = col_character(),
#   nb_mplacements = col_double(),
#   emplacements_disponibles = col_double(),
#   velos_disponibles = col_double(),
#   date = col_datetime(format = "")
# )
# Parsed with column specification:
# cols(
#   id = col_double(),
#   nom = col_character(),
#   adresse_numero = col_character(),
#   adresse_voie = col_character(),
#   commune = col_character(),
#   latitude = col_double(),
#   longitude = col_double(),
#   id_correspondance = col_double(),
#   mise_en_service = col_date(format = ""),
#   nb_emplacements = col_double(),
#   `id_proche1` = col_double(),
#   `id_proche2` = col_double(),
#   `id_proche3` = col_double(),
#   terminal_cb = col_logical()
# )

# %%
distance <- function(x,y){
    point <- c(48.1179151,-1.7028661)
    dist <- sqrt((point[1] - x)**2 + (point[2] - y)**2)
    return(dist)
}

# %%
topo %>%
mutate(dist = distance(`latitude`,`longitude`))
# Out:
#     id  nom                  adresse_numero
# 1    1  République           19
# 2    2  Mairie               12
# 3    3  Champ Jacquet        8
# 4   10  Musée Beaux-Arts     3
# 5   12  TNB                  1
# 6   14  Laënnec              11
# 7   17  Charles de Gaulle    2
# 8   20  Pont de Nantes       32
# 9   22  Oberthur             4
# 10  25  Office de Tourisme   2
# 11  26  Les Lices            9
# 12  29  Jules Ferry          103
# 13  33  Anatole France       3
# 14  41  Cimetière Est        78
# 15  43  Cité Judiciaire      20
# 16  44  Metz - Sévigné       28
# 17  49  Beaulieu Diapason    NA
# 18  52  Villejean-Université NA
# 19  60  Cucillé              14
# 20  61  Jacques Cartier      155
# 21  72  Cleunay              24
# 22  73  Géniaux              101
# 23  76  Monts d'Arrée        3
# 24  80  Painlevé             197
# 25   6  Hôtel Dieu           2
# 26  21  Les Halles           32
# 27  27  Horizons             6
# 28  30  Guéhenno - Fougères  121
# ...

# %%
point <- c(48.1179151,-1.7028661)
topo %>%
mutate(dist = sqrt((point[1] - latitude)**2 + (point[2] - longitude)**2))
# Out:
#     id  nom                  adresse_numero
# 1    1  République           19
# 2    2  Mairie               12
# 3    3  Champ Jacquet        8
# 4   10  Musée Beaux-Arts     3
# 5   12  TNB                  1
# 6   14  Laënnec              11
# 7   17  Charles de Gaulle    2
# 8   20  Pont de Nantes       32
# 9   22  Oberthur             4
# 10  25  Office de Tourisme   2
# 11  26  Les Lices            9
# 12  29  Jules Ferry          103
# 13  33  Anatole France       3
# 14  41  Cimetière Est        78
# 15  43  Cité Judiciaire      20
# 16  44  Metz - Sévigné       28
# 17  49  Beaulieu Diapason    NA
# 18  52  Villejean-Université NA
# 19  60  Cucillé              14
# 20  61  Jacques Cartier      155
# 21  72  Cleunay              24
# 22  73  Géniaux              101
# 23  76  Monts d'Arrée        3
# 24  80  Painlevé             197
# 25   6  Hôtel Dieu           2
# 26  21  Les Halles           32
# 27  27  Horizons             6
# 28  30  Guéhenno - Fougères  121
# ...
